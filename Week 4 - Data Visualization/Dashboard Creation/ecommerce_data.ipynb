# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_ec = pd.read_csv("ecommerce.csv")
df_ec
# Out:
#        day  month  quarter  year     category       item  price
# 0        1      1        1  2020  Electronics     Tablet   1131
# 1        1      1        1  2020       Ebooks    Fiction     15
# 2        1      1        1  2020  Electronics     Laptop    866
# 3        1      1        1  2020  Electronics     Mobile    903
# 4        1      1        1  2020       Ebooks    Fiction      8
# ...    ...    ...      ...   ...          ...        ...    ...
# 67998   31     12        4  2020       Ebooks  Self Help     15
# 67999   31     12        4  2020       Ebooks  Technical     41
# 68000   31     12        4  2020        Music        Pop     13
# 68001   31     12        4  2020  Electronics     Tablet   1444
# 68002   31     12        4  2020  Electronics     Mobile    774
#
# [68003 rows x 7 columns]

# %%
df_ec.head(10)
# Out:
#    day  month  quarter  year     category       item  price
# 0    1      1        1  2020  Electronics     Tablet   1131
# 1    1      1        1  2020       Ebooks    Fiction     15
# 2    1      1        1  2020  Electronics     Laptop    866
# 3    1      1        1  2020  Electronics     Mobile    903
# 4    1      1        1  2020       Ebooks    Fiction      8
# 5    1      1        1  2020       Ebooks  Self Help      7
# 6    1      1        1  2020        Music        Pop     11
# 7    1      1        1  2020       Ebooks    Fiction      9
# 8    1      1        1  2020        Music        Pop     13
# 9    1      1        1  2020        Music        Pop     14

# %%
df_count = df_ec.groupby(['category']).count()
df_count.plot(kind = 'pie', y='price', autopct = '%1.0f%%')
plt.title("Category wise sales")
plt.show()

# %%
df_ec[['category']].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='category'>

# %%
df_quarters = df_ec[df_ec['item'] == 'Mobile'].groupby(['quarter']).sum()
df_quarters[['price']].plot(kind='barh')
plt.title("Mobile sales per quarter")
plt.show()

# %%
df_ec[['quarter']].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='quarter'>

# %%
import seaborn as sns
df_month = df_ec.groupby(['month']).sum()
df_month = df_month.reset_index()
sns.scatterplot(x = 'month', y = 'price', data=df_month, hue = 'month', legend=None)
sns.lineplot(x = 'month', y = 'price', data = df_month)
plt.title("Month wise sales")
# Out:
# Text(0.5, 1.0, 'Month wise sales')
